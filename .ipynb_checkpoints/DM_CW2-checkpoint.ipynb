# %%
import pandas as pd
import numpy as np
pd.set_option('max_rows', 10)
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
print("Vis setup Complete")
print("Setup complete.")
# Out:
# Vis setup Complete
# Setup complete.

# %%
loan_data_path = "J:\LendingClubLoans2018-2020.csv";
loan_data = pd.read_csv(loan_data_path)
loan_data.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77159 entries, 0 to 77158
# Data columns (total 108 columns):
#  #   Column                                      Dtype
# ---  ------                                      -----
#  0   id                                          int64
#  1   emp_title                                   object
#  2   application_type                            object
#  3   home_ownership                              object
#  4   loan_status                                 object
#  5   loan_amnt                                   int64
#  6   int_rate                                    object
#  7   term                                        object
#  8   installment                                 float64
#  9   grade                                       object
#  10  earliest_cr_line                            object
#  11  issue_d                                     object
#  12  last_pymnt_d                                object
#  13  next_pymnt_d                                object
#  14  annual_inc                                  float64
#  15  annual_inc_joint                            float64
#  16  verification_status                         object
#  17  verification_status_joint                   object
#  18  pymnt_plan                                  object
#  19  purpose                                     object
#  20  hardship_flag                               object
#  21  hardship_reason                             object
#  22  hardship_type                               object
#  23  hardship_status                             object
#  24  payment_plan_start_date                     object
#  25  dti                                         float64
#  26  dti_joint                                   float64
#  27  delinq_2yrs                                 int64
#  28  inq_fi                                      float64
#  29  inq_last_12m                                float64
#  30  inq_last_6mths                              int64
#  31  fico_range_low                              int64
#  32  fico_range_high                             int64
#  33  last_fico_range_high                        int64
#  34  last_fico_range_low                         int64
#  35  mort_acc                                    int64
#  36  open_acc                                    int64
#  37  open_acc_6m                                 float64
#  38  acc_open_past_24mths                        int64
#  39  pub_rec                                     int64
#  40  total_acc                                   int64
#  41  initial_list_status                         object
#  42  out_prncp                                   float64
#  43  out_prncp_inv                               float64
#  44  total_pymnt                                 float64
#  45  total_pymnt_inv                             float64
#  46  total_rec_prncp                             float64
#  47  total_rec_int                               float64
#  48  total_rec_late_fee                          float64
#  49  total_cu_tl                                 float64
#  50  tot_coll_amt                                int64
#  51  tot_cur_bal                                 int64
#  52  total_bal_il                                float64
#  53  total_rev_hi_lim                            int64
#  54  tot_hi_cred_lim                             int64
#  55  total_bal_ex_mort                           int64
#  56  total_bc_limit                              int64
#  57  total_il_high_credit_limit                  int64
#  58  mths_since_last_record                      float64
#  59  mths_since_last_major_derog                 float64
#  60  mths_since_recent_bc                        float64
#  61  mths_since_recent_bc_dlq                    float64
#  62  mths_since_recent_inq                       float64
#  63  mths_since_rcnt_il                          float64
#  64  mths_since_last_delinq                      float64
#  65  mths_since_recent_revol_delinq              float64
#  66  mo_sin_old_il_acct                          float64
#  67  mo_sin_old_rev_tl_op                        int64
#  68  mo_sin_rcnt_rev_tl_op                       int64
#  69  mo_sin_rcnt_tl                              int64
#  70  open_act_il                                 float64
#  71  open_il_12m                                 float64
#  72  open_il_24m                                 float64
#  73  il_util                                     float64
#  74  bc_util                                     float64
#  75  all_util                                    float64
#  76  revol_util                                  object
#  77  open_rv_12m                                 float64
#  78  open_rv_24m                                 float64
#  79  max_bal_bc                                  float64
#  80  avg_cur_bal                                 float64
#  81  bc_open_to_buy                              float64
#  82  recoveries                                  float64
#  83  chargeoff_within_12_mths                    int64
#  84  collection_recovery_fee                     float64
#  85  collections_12_mths_ex_med                  int64
#  86  num_accts_ever_120_pd                       int64
#  87  num_actv_bc_tl                              int64
#  88  num_actv_rev_tl                             int64
#  89  num_bc_sats                                 int64
#  90  num_bc_tl                                   int64
#  91  num_il_tl                                   int64
#  92  num_op_rev_tl                               int64
#  93  num_rev_accts                               int64
#  94  num_rev_tl_bal_gt_0                         int64
#  95  num_sats                                    int64
#  96  num_tl_90g_dpd_24m                          int64
#  97  num_tl_op_past_12m                          int64
#  98  pct_tl_nvr_dlq                              float64
#  99  percent_bc_gt_75                            float64
#  100 pub_rec_bankruptcies                        int64
#  101 tax_liens                                   int64
#  102 revol_bal_joint                             float64
#  103 deferral_term                               float64
#  104 hardship_amount                             float64
#  105 hardship_payoff_balance_amount              float64
#  106 hardship_last_payment_amount                float64
#  107 orig_projected_additional_accrued_interest  float64
# dtypes: float64(47), int64(39), object(22)
# memory usage: 63.6+ MB

# %%
feature_missing_values = loan_data.isna().sum()
feature_missing_values = feature_missing_values.to_frame('Missing_Values')

# %%
percenatges_df = (loan_data.isna().sum()* 100 / len(loan_data)).to_frame('Missing_Percentages')
missing_values_stats_df = pd.concat([feature_missing_values, percenatges_df], axis=1)
missing_values_stats_df
# Out:
#                                             Missing_Values  \
# id                                                       0
# emp_title                                             5862
# application_type                                         0
# home_ownership                                           0
# loan_status                                              0
# ...                                                    ...
# deferral_term                                        72668
# hardship_amount                                      71042
# hardship_payoff_balance_amount                       71042
# hardship_last_payment_amount                         71042
# orig_projected_additional_accrued_interest           71170
#
#                                             Missing_Percentages
# id                                                     0.000000
# emp_title                                              7.597299
# application_type                                       0.000000
# home_ownership                                         0.000000
# loan_status                                            0.000000
# ...                                                         ...
# deferral_term                                         94.179551
# hardship_amount                                       92.072215
# hardship_payoff_balance_amount                        92.072215
# hardship_last_payment_amount                          92.072215
# orig_projected_additional_accrued_interest            92.238106
#
# [108 rows x 2 columns]

# %%
missing_values_stats_df.loc['deferral_term']
# Out:
# Missing_Values         72668.000000
# Missing_Percentages       94.179551
# Name: deferral_term, dtype: float64

# %%
missing_values_stats_df[missing_values_stats_df['Missing_Percentages'] > 60]
# Out:
#                                             Missing_Values  \
# annual_inc_joint                                     67777
# verification_status_joint                            67780
# hardship_reason                                      72668
# hardship_type                                        72668
# hardship_status                                      72668
# ...                                                    ...
# deferral_term                                        72668
# hardship_amount                                      71042
# hardship_payoff_balance_amount                       71042
# hardship_last_payment_amount                         71042
# orig_projected_additional_accrued_interest           71170
#
#                                             Missing_Percentages
# annual_inc_joint                                      87.840693
# verification_status_joint                             87.844581
# hardship_reason                                       94.179551
# hardship_type                                         94.179551
# hardship_status                                       94.179551
# ...                                                         ...
# deferral_term                                         94.179551
# hardship_amount                                       92.072215
# hardship_payoff_balance_amount                        92.072215
# hardship_last_payment_amount                          92.072215
# orig_projected_additional_accrued_interest            92.238106
#
# [17 rows x 2 columns]

# %%
more_null_values = []
for index, row in missing_values_stats_df.iterrows():
    if (row['Missing_Percentages'] > 60):
        more_null_values.append(index)

# %%
print('Number of Features which has more than 60 peercent of null values: ', len(more_null_values))
more_null_values
# Out:
# Number of Features which has more than 60 peercent of null values:  17
# ['annual_inc_joint',
#  'verification_status_joint',
#  'hardship_reason',
#  'hardship_type',
#  'hardship_status',
#  'payment_plan_start_date',
#  'dti_joint',
#  'mths_since_last_record',
#  'mths_since_last_major_derog',
#  'mths_since_recent_bc_dlq',
#  'mths_since_recent_revol_delinq',
#  'revol_bal_joint',
#  'deferral_term',
#  'hardship_amount',
#  'hardship_payoff_balance_amount',
#  'hardship_last_payment_amount',
#  'orig_projected_additional_accrued_interest']

# %%
new_loan_df = loan_data.drop(more_null_values, axis=1)
new_loan_df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77159 entries, 0 to 77158
# Data columns (total 91 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          77159 non-null  int64
#  1   emp_title                   71297 non-null  object
#  2   application_type            77159 non-null  object
#  3   home_ownership              77159 non-null  object
#  4   loan_status                 77159 non-null  object
#  5   loan_amnt                   77159 non-null  int64
#  6   int_rate                    77159 non-null  object
#  7   term                        77159 non-null  object
#  8   installment                 77159 non-null  float64
#  9   grade                       77159 non-null  object
#  10  earliest_cr_line            77159 non-null  object
#  11  issue_d                     77159 non-null  object
#  12  last_pymnt_d                77159 non-null  object
#  13  next_pymnt_d                33256 non-null  object
#  14  annual_inc                  77159 non-null  float64
#  15  verification_status         77159 non-null  object
#  16  pymnt_plan                  77159 non-null  object
#  17  purpose                     77159 non-null  object
#  18  hardship_flag               75532 non-null  object
#  19  dti                         77051 non-null  float64
#  20  delinq_2yrs                 77159 non-null  int64
#  21  inq_fi                      74664 non-null  float64
#  22  inq_last_12m                74664 non-null  float64
#  23  inq_last_6mths              77159 non-null  int64
#  24  fico_range_low              77159 non-null  int64
#  25  fico_range_high             77159 non-null  int64
#  26  last_fico_range_high        77159 non-null  int64
#  27  last_fico_range_low         77159 non-null  int64
#  28  mort_acc                    77159 non-null  int64
#  29  open_acc                    77159 non-null  int64
#  30  open_acc_6m                 74664 non-null  float64
#  31  acc_open_past_24mths        77159 non-null  int64
#  32  pub_rec                     77159 non-null  int64
#  33  total_acc                   77159 non-null  int64
#  34  initial_list_status         77159 non-null  object
#  35  out_prncp                   77159 non-null  float64
#  36  out_prncp_inv               77159 non-null  float64
#  37  total_pymnt                 77159 non-null  float64
#  38  total_pymnt_inv             77159 non-null  float64
#  39  total_rec_prncp             77159 non-null  float64
#  40  total_rec_int               77159 non-null  float64
#  41  total_rec_late_fee          77159 non-null  float64
#  42  total_cu_tl                 74664 non-null  float64
#  43  tot_coll_amt                77159 non-null  int64
#  44  tot_cur_bal                 77159 non-null  int64
#  45  total_bal_il                74664 non-null  float64
#  46  total_rev_hi_lim            77159 non-null  int64
#  47  tot_hi_cred_lim             77159 non-null  int64
#  48  total_bal_ex_mort           77159 non-null  int64
#  49  total_bc_limit              77159 non-null  int64
#  50  total_il_high_credit_limit  77159 non-null  int64
#  51  mths_since_recent_bc        76112 non-null  float64
#  52  mths_since_recent_inq       67916 non-null  float64
#  53  mths_since_rcnt_il          72280 non-null  float64
#  54  mths_since_last_delinq      37514 non-null  float64
#  55  mo_sin_old_il_acct          74722 non-null  float64
#  56  mo_sin_old_rev_tl_op        77159 non-null  int64
#  57  mo_sin_rcnt_rev_tl_op       77159 non-null  int64
#  58  mo_sin_rcnt_tl              77159 non-null  int64
#  59  open_act_il                 74664 non-null  float64
#  60  open_il_12m                 74664 non-null  float64
#  61  open_il_24m                 74664 non-null  float64
#  62  il_util                     63897 non-null  float64
#  63  bc_util                     76005 non-null  float64
#  64  all_util                    74648 non-null  float64
#  65  revol_util                  77056 non-null  object
#  66  open_rv_12m                 74664 non-null  float64
#  67  open_rv_24m                 74664 non-null  float64
#  68  max_bal_bc                  74664 non-null  float64
#  69  avg_cur_bal                 77152 non-null  float64
#  70  bc_open_to_buy              76043 non-null  float64
#  71  recoveries                  77159 non-null  float64
#  72  chargeoff_within_12_mths    77159 non-null  int64
#  73  collection_recovery_fee     77159 non-null  float64
#  74  collections_12_mths_ex_med  77159 non-null  int64
#  75  num_accts_ever_120_pd       77159 non-null  int64
#  76  num_actv_bc_tl              77159 non-null  int64
#  77  num_actv_rev_tl             77159 non-null  int64
#  78  num_bc_sats                 77159 non-null  int64
#  79  num_bc_tl                   77159 non-null  int64
#  80  num_il_tl                   77159 non-null  int64
#  81  num_op_rev_tl               77159 non-null  int64
#  82  num_rev_accts               77159 non-null  int64
#  83  num_rev_tl_bal_gt_0         77159 non-null  int64
#  84  num_sats                    77159 non-null  int64
#  85  num_tl_90g_dpd_24m          77159 non-null  int64
#  86  num_tl_op_past_12m          77159 non-null  int64
#  87  pct_tl_nvr_dlq              77154 non-null  float64
#  88  percent_bc_gt_75            76040 non-null  float64
#  89  pub_rec_bankruptcies        77159 non-null  int64
#  90  tax_liens                   77159 non-null  int64
# dtypes: float64(35), int64(39), object(17)
# memory usage: 53.6+ MB

# %%
categorical_features = new_loan_df.select_dtypes(exclude=[np.number])
print(len(categorical_features.columns))
categorical_features
# new_loan_df[dtype="string"]
# Out:
# 17
#                    emp_title application_type home_ownership  loan_status  \
# 0                  Stagehand       Individual           RENT   Fully Paid
# 1           Detention Deputy       Individual           RENT  Charged Off
# 2                        NaN       Individual       MORTGAGE      Current
# 3                     Driver       Individual           RENT   Fully Paid
# 4            JP Morgan Chase       Individual       MORTGAGE   Fully Paid
# ...                      ...              ...            ...          ...
# 77154             IT analyst       Individual       MORTGAGE      Current
# 77155  Principal IA Engineer       Individual       MORTGAGE      Current
# 77156               Attorney       Individual           RENT   Fully Paid
# 77157                 Pastor       Individual            OWN   Fully Paid
# 77158               strander       Individual       MORTGAGE   Fully Paid
#
#       int_rate       term grade earliest_cr_line    issue_d last_pymnt_d  \
# 0       15.05%  36 months     C           Jan-01   8/1/2017     4/1/2020
# 1       14.08%  60 months     C           Dec-00   7/1/2017     6/1/2019
# 2       14.08%  60 months     C           Apr-86   7/1/2017     5/1/2020
# 3       19.03%  36 months     D           Feb-90   8/1/2017    10/1/2019
# 4        8.90%  60 months     A           Mar-88   8/1/2013     1/1/2019
# ...        ...        ...   ...              ...        ...          ...
# 77154   15.05%  36 months     C           Mar-95   9/1/2017     5/1/2020
# 77155    7.97%  36 months     A           Dec-02   9/1/2017     5/1/2020
# 77156    5.32%  36 months     A           Aug-99  12/1/2017     5/1/2018
# 77157   20.00%  36 months     D           Jan-07   8/1/2017     6/1/2018
# 77158    9.93%  36 months     B           Oct-97   9/1/2017    11/1/2018
#
#       next_pymnt_d verification_status pymnt_plan             purpose  \
# 0              NaN            Verified          n  debt_consolidation
# 1              NaN        Not Verified          n  debt_consolidation
# 2           Jun-20            Verified          n    home_improvement
# 3              NaN     Source Verified          n  debt_consolidation
# 4              NaN            Verified          n  debt_consolidation
# ...            ...                 ...        ...                 ...
# 77154       Jun-20            Verified          n               other
# 77155       Jun-20        Not Verified          n    home_improvement
# 77156          NaN        Not Verified          n  debt_consolidation
# 77157          NaN     Source Verified          n  debt_consolidation
# 77158          NaN            Verified          n               other
#
#       hardship_flag initial_list_status revol_util
# 0                 N                   w     56.30%
# 1                 N                   w     43.50%
# 2                 N                   w      9.70%
# 3                 N                   w     86.90%
# 4                 N                   w     24.20%
# ...             ...                 ...        ...
# 77154             N                   w        77%
# 77155             N                   w        59%
# 77156             N                   w         4%
# 77157             N                   w     72.70%
# 77158             N                   f     86.50%
#
# [77159 rows x 17 columns]

# %%
categorical_features.describe()
# Out:
#        emp_title application_type home_ownership loan_status int_rate  \
# count      71297            77159          77159       77159    77159
# unique     28185                2              5           7      129
# top      Teacher       Individual       MORTGAGE  Fully Paid   16.02%
# freq        1658            67777          37334       34289     5181
#
#              term  grade earliest_cr_line   issue_d last_pymnt_d next_pymnt_d  \
# count       77159  77159            77159     77159        77159        33256
# unique          2      7              622        16           28            9
# top     36 months      C           Sep-05  8/1/2017     5/1/2020       Jun-20
# freq        52800  25152              665     17934        32333        29658
#
#        verification_status pymnt_plan             purpose hardship_flag  \
# count                77159      77159               77159         75532
# unique                   3          1                  13             2
# top        Source Verified          n  debt_consolidation             N
# freq                 28886      77159               42980         71962
#
#        initial_list_status revol_util
# count                77159      77056
# unique                   2       1074
# top                      w         0%
# freq                 61477        509

# %%
features_for_One_hot = [
    'application_type',
    'hardship_flag',
    'initial_list_status',
]

features_for_ordinal_encoder = [
    'home_ownership',
    'grade',
    'purpose',
    'verification_status'
]

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
for i in features_for_One_hot:    
    # integer encode
    label_encoder = LabelEncoder()
    integer_encoded = label_encoder.fit_transform(new_loan_df[i])
    
    # binary encode
    onehot_encoder = OneHotEncoder(sparse=False)
    integer_encoded = integer_encoded.reshape(len(integer_encoded), 1)
    new_loan_df[i] = onehot_encoder.fit_transform(integer_encoded)
new_loan_df[features_for_One_hot]
# Out:
#        application_type  hardship_flag  initial_list_status
# 0                   1.0            1.0                  0.0
# 1                   1.0            1.0                  0.0
# 2                   1.0            1.0                  0.0
# 3                   1.0            1.0                  0.0
# 4                   1.0            1.0                  0.0
# ...                 ...            ...                  ...
# 77154               1.0            1.0                  0.0
# 77155               1.0            1.0                  0.0
# 77156               1.0            1.0                  0.0
# 77157               1.0            1.0                  0.0
# 77158               1.0            1.0                  1.0
#
# [77159 rows x 3 columns]

# %%
new_loan_df['initial_list_status'].unique()
# Out:
# array([0., 1.])

# %%
import category_encoders as ce
enc = ce.OrdinalEncoder(cols=features_for_ordinal_encoder, handle_missing='return_nan', return_df= True)

#We now fit the model and transform the data and put it in X which is a dataframe
transformed_loan_df=enc.fit_transform(new_loan_df)
type(transformed_loan_df)
# Out:
# C:\Users\Waqar Ayub\anaconda3\lib\site-packages\category_encoders\utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):
# pandas.core.frame.DataFrame

# %%
# transformed_loan_df['int_rate'] = transformed_loan_df['int_rate'].str.split('%').str[0]
transformed_loan_df['int_rate'] = transformed_loan_df['int_rate'].str.rstrip('%').astype('float') / 100.0
transformed_loan_df['int_rate']
# Out:
# 0        0.1505
# 1        0.1408
# 2        0.1408
# 3        0.1903
# 4        0.0890
#           ...
# 77154    0.1505
# 77155    0.0797
# 77156    0.0532
# 77157    0.2000
# 77158    0.0993
# Name: int_rate, Length: 77159, dtype: float64

# %%
# transformed_loan_df['int_rate'] = transformed_loan_df['int_rate'].str.rstrip('%').astype('float') / 100.0
# transformed_loan_df['int_rate']

# %%
print(int(transformed_loan_df['term'][0].split(' ')[0]))
transformed_loan_df['term'] = [int(str(val).split(' ')[0]) for val in transformed_loan_df['term'].values]
transformed_loan_df['term']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-189-eb50434902c8> in <module>
# ----> 1 print(int(transformed_loan_df['term'][0].split(' ')[0]))
#       2 transformed_loan_df['term'] = [float(str(val).split(' ')[0]) for val in transformed_loan_df['term'].values]
#       3 transformed_loan_df['term']
#
# AttributeError: 'numpy.float64' object has no attribute 'split'

# %%
transformed_loan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77159 entries, 0 to 77158
# Data columns (total 91 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          77159 non-null  int64
#  1   emp_title                   71297 non-null  object
#  2   application_type            77159 non-null  float64
#  3   home_ownership              77159 non-null  float64
#  4   loan_status                 77159 non-null  object
#  5   loan_amnt                   77159 non-null  int64
#  6   int_rate                    77159 non-null  float64
#  7   term                        77159 non-null  object
#  8   installment                 77159 non-null  float64
#  9   grade                       77159 non-null  float64
#  10  earliest_cr_line            77159 non-null  object
#  11  issue_d                     77159 non-null  object
#  12  last_pymnt_d                77159 non-null  object
#  13  next_pymnt_d                33256 non-null  object
#  14  annual_inc                  77159 non-null  float64
#  15  verification_status         77159 non-null  float64
#  16  pymnt_plan                  77159 non-null  object
#  17  purpose                     77159 non-null  float64
#  18  hardship_flag               77159 non-null  float64
#  19  dti                         77051 non-null  float64
#  20  delinq_2yrs                 77159 non-null  int64
#  21  inq_fi                      74664 non-null  float64
#  22  inq_last_12m                74664 non-null  float64
#  23  inq_last_6mths              77159 non-null  int64
#  24  fico_range_low              77159 non-null  int64
#  25  fico_range_high             77159 non-null  int64
#  26  last_fico_range_high        77159 non-null  int64
#  27  last_fico_range_low         77159 non-null  int64
#  28  mort_acc                    77159 non-null  int64
#  29  open_acc                    77159 non-null  int64
#  30  open_acc_6m                 74664 non-null  float64
#  31  acc_open_past_24mths        77159 non-null  int64
#  32  pub_rec                     77159 non-null  int64
#  33  total_acc                   77159 non-null  int64
#  34  initial_list_status         77159 non-null  float64
#  35  out_prncp                   77159 non-null  float64
#  36  out_prncp_inv               77159 non-null  float64
#  37  total_pymnt                 77159 non-null  float64
#  38  total_pymnt_inv             77159 non-null  float64
#  39  total_rec_prncp             77159 non-null  float64
#  40  total_rec_int               77159 non-null  float64
#  41  total_rec_late_fee          77159 non-null  float64
#  42  total_cu_tl                 74664 non-null  float64
#  43  tot_coll_amt                77159 non-null  int64
#  44  tot_cur_bal                 77159 non-null  int64
#  45  total_bal_il                74664 non-null  float64
#  46  total_rev_hi_lim            77159 non-null  int64
#  47  tot_hi_cred_lim             77159 non-null  int64
#  48  total_bal_ex_mort           77159 non-null  int64
#  49  total_bc_limit              77159 non-null  int64
#  50  total_il_high_credit_limit  77159 non-null  int64
#  51  mths_since_recent_bc        76112 non-null  float64
#  52  mths_since_recent_inq       67916 non-null  float64
#  53  mths_since_rcnt_il          72280 non-null  float64
#  54  mths_since_last_delinq      37514 non-null  float64
#  55  mo_sin_old_il_acct          74722 non-null  float64
#  56  mo_sin_old_rev_tl_op        77159 non-null  int64
#  57  mo_sin_rcnt_rev_tl_op       77159 non-null  int64
#  58  mo_sin_rcnt_tl              77159 non-null  int64
#  59  open_act_il                 74664 non-null  float64
#  60  open_il_12m                 74664 non-null  float64
#  61  open_il_24m                 74664 non-null  float64
#  62  il_util                     63897 non-null  float64
#  63  bc_util                     76005 non-null  float64
#  64  all_util                    74648 non-null  float64
#  65  revol_util                  77056 non-null  object
#  66  open_rv_12m                 74664 non-null  float64
#  67  open_rv_24m                 74664 non-null  float64
#  68  max_bal_bc                  74664 non-null  float64
#  69  avg_cur_bal                 77152 non-null  float64
#  70  bc_open_to_buy              76043 non-null  float64
#  71  recoveries                  77159 non-null  float64
#  72  chargeoff_within_12_mths    77159 non-null  int64
#  73  collection_recovery_fee     77159 non-null  float64
#  74  collections_12_mths_ex_med  77159 non-null  int64
#  75  num_accts_ever_120_pd       77159 non-null  int64
#  76  num_actv_bc_tl              77159 non-null  int64
#  77  num_actv_rev_tl             77159 non-null  int64
#  78  num_bc_sats                 77159 non-null  int64
#  79  num_bc_tl                   77159 non-null  int64
#  80  num_il_tl                   77159 non-null  int64
#  81  num_op_rev_tl               77159 non-null  int64
#  82  num_rev_accts               77159 non-null  int64
#  83  num_rev_tl_bal_gt_0         77159 non-null  int64
#  84  num_sats                    77159 non-null  int64
#  85  num_tl_90g_dpd_24m          77159 non-null  int64
#  86  num_tl_op_past_12m          77159 non-null  int64
#  87  pct_tl_nvr_dlq              77154 non-null  float64
#  88  percent_bc_gt_75            76040 non-null  float64
#  89  pub_rec_bankruptcies        77159 non-null  int64
#  90  tax_liens                   77159 non-null  int64
# dtypes: float64(43), int64(39), object(9)
# memory usage: 53.6+ MB

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-165-9c2f8dc4ae55> in <module>
#       1 # transformed_loan_df['int_rate'] = transformed_loan_df['int_rate'].str.split('%').str[0]
# ----> 2 transformed_loan_df['int_rate'] = transformed_loan_df['int_rate'].str.rstrip('%').astype('float') / 100.0
#       3 transformed_loan_df['int_rate']
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5133             or name in self._accessors
#    5134         ):
# -> 5135             return object.__getattribute__(self, name)
#    5136         else:
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     185             # we're accessing the attribute of the class, i.e., Dataset.geo
#     186             return self._accessor
# --> 187         accessor_obj = self._accessor(obj)
#     188         # Replace the property with the accessor object. Inspired by:
#     189         # https://www.pydanny.com/cached-property.html
#
# ~\anaconda3\lib\site-packages\pandas\core\strings.py in __init__(self, data)
#    2098
#    2099     def __init__(self, data):
# -> 2100         self._inferred_dtype = self._validate(data)
#    2101         self._is_categorical = is_categorical_dtype(data.dtype)
#    2102         self._is_string = data.dtype.name == "string"
#
# ~\anaconda3\lib\site-packages\pandas\core\strings.py in _validate(data)
#    2155
#    2156         if inferred_dtype not in allowed_types:
# -> 2157             raise AttributeError("Can only use .str accessor with string values!")
#    2158         return inferred_dtype
#    2159
#
# AttributeError: Can only use .str accessor with string values!

# %%
loan_copy = new_loan_df
loan_copy['earliest_cr_line_year'] = loan_copy['earliest_cr_line'].str.split('-').str[1]
loan_copy['earliest_cr_line_month'] = loan_copy['earliest_cr_line'].str.split('-').str[0]
loan_copy[['earliest_cr_line_year', 'earliest_cr_line_month']]

loan_copy['earliest_cr_line_year'] = loan_copy[loan_copy[earliest_cr_line_year][0]]
# Out:
#       earliest_cr_line_year earliest_cr_line_month
# 0                        01                    Jan
# 1                        00                    Dec
# 2                        86                    Apr
# 3                        90                    Feb
# 4                        88                    Mar
# ...                     ...                    ...
# 77154                    95                    Mar
# 77155                    02                    Dec
# 77156                    99                    Aug
# 77157                    07                    Jan
# 77158                    97                    Oct
#
# [77159 rows x 2 columns]

# %%
categorical_features_of_interest = [
    'emp_title', 
    'application_type', 
    'home_ownership',
    'term',
    'grade',
    'verification_status',
    'purpose',
    'hardship_flag',
    'revol_util',
    'int_rate'
]

import category_encoders as ce
enc = ce.OrdinalEncoder(cols=categorical_features_of_interest, handle_missing='return_nan', return_df= True)

#We now fit the model and transform the data and put it in X which is a dataframe
transformed_loan_df=enc.fit_transform(new_loan_df)
type(transformed_loan_df)
# Out:
# C:\Users\Waqar Ayub\anaconda3\lib\site-packages\category_encoders\utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):
# pandas.core.frame.DataFrame

# %%
transformed_loan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77159 entries, 0 to 77158
# Data columns (total 91 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          77159 non-null  int64
#  1   emp_title                   71297 non-null  float64
#  2   application_type            77159 non-null  float64
#  3   home_ownership              77159 non-null  float64
#  4   loan_status                 77159 non-null  object
#  5   loan_amnt                   77159 non-null  int64
#  6   int_rate                    77159 non-null  float64
#  7   term                        77159 non-null  float64
#  8   installment                 77159 non-null  float64
#  9   grade                       77159 non-null  float64
#  10  earliest_cr_line            77159 non-null  object
#  11  issue_d                     77159 non-null  object
#  12  last_pymnt_d                77159 non-null  object
#  13  next_pymnt_d                33256 non-null  object
#  14  annual_inc                  77159 non-null  float64
#  15  verification_status         77159 non-null  float64
#  16  pymnt_plan                  77159 non-null  object
#  17  purpose                     77159 non-null  float64
#  18  hardship_flag               75532 non-null  float64
#  19  dti                         77051 non-null  float64
#  20  delinq_2yrs                 77159 non-null  int64
#  21  inq_fi                      74664 non-null  float64
#  22  inq_last_12m                74664 non-null  float64
#  23  inq_last_6mths              77159 non-null  int64
#  24  fico_range_low              77159 non-null  int64
#  25  fico_range_high             77159 non-null  int64
#  26  last_fico_range_high        77159 non-null  int64
#  27  last_fico_range_low         77159 non-null  int64
#  28  mort_acc                    77159 non-null  int64
#  29  open_acc                    77159 non-null  int64
#  30  open_acc_6m                 74664 non-null  float64
#  31  acc_open_past_24mths        77159 non-null  int64
#  32  pub_rec                     77159 non-null  int64
#  33  total_acc                   77159 non-null  int64
#  34  initial_list_status         77159 non-null  object
#  35  out_prncp                   77159 non-null  float64
#  36  out_prncp_inv               77159 non-null  float64
#  37  total_pymnt                 77159 non-null  float64
#  38  total_pymnt_inv             77159 non-null  float64
#  39  total_rec_prncp             77159 non-null  float64
#  40  total_rec_int               77159 non-null  float64
#  41  total_rec_late_fee          77159 non-null  float64
#  42  total_cu_tl                 74664 non-null  float64
#  43  tot_coll_amt                77159 non-null  int64
#  44  tot_cur_bal                 77159 non-null  int64
#  45  total_bal_il                74664 non-null  float64
#  46  total_rev_hi_lim            77159 non-null  int64
#  47  tot_hi_cred_lim             77159 non-null  int64
#  48  total_bal_ex_mort           77159 non-null  int64
#  49  total_bc_limit              77159 non-null  int64
#  50  total_il_high_credit_limit  77159 non-null  int64
#  51  mths_since_recent_bc        76112 non-null  float64
#  52  mths_since_recent_inq       67916 non-null  float64
#  53  mths_since_rcnt_il          72280 non-null  float64
#  54  mths_since_last_delinq      37514 non-null  float64
#  55  mo_sin_old_il_acct          74722 non-null  float64
#  56  mo_sin_old_rev_tl_op        77159 non-null  int64
#  57  mo_sin_rcnt_rev_tl_op       77159 non-null  int64
#  58  mo_sin_rcnt_tl              77159 non-null  int64
#  59  open_act_il                 74664 non-null  float64
#  60  open_il_12m                 74664 non-null  float64
#  61  open_il_24m                 74664 non-null  float64
#  62  il_util                     63897 non-null  float64
#  63  bc_util                     76005 non-null  float64
#  64  all_util                    74648 non-null  float64
#  65  revol_util                  77056 non-null  float64
#  66  open_rv_12m                 74664 non-null  float64
#  67  open_rv_24m                 74664 non-null  float64
#  68  max_bal_bc                  74664 non-null  float64
#  69  avg_cur_bal                 77152 non-null  float64
#  70  bc_open_to_buy              76043 non-null  float64
#  71  recoveries                  77159 non-null  float64
#  72  chargeoff_within_12_mths    77159 non-null  int64
#  73  collection_recovery_fee     77159 non-null  float64
#  74  collections_12_mths_ex_med  77159 non-null  int64
#  75  num_accts_ever_120_pd       77159 non-null  int64
#  76  num_actv_bc_tl              77159 non-null  int64
#  77  num_actv_rev_tl             77159 non-null  int64
#  78  num_bc_sats                 77159 non-null  int64
#  79  num_bc_tl                   77159 non-null  int64
#  80  num_il_tl                   77159 non-null  int64
#  81  num_op_rev_tl               77159 non-null  int64
#  82  num_rev_accts               77159 non-null  int64
#  83  num_rev_tl_bal_gt_0         77159 non-null  int64
#  84  num_sats                    77159 non-null  int64
#  85  num_tl_90g_dpd_24m          77159 non-null  int64
#  86  num_tl_op_past_12m          77159 non-null  int64
#  87  pct_tl_nvr_dlq              77154 non-null  float64
#  88  percent_bc_gt_75            76040 non-null  float64
#  89  pub_rec_bankruptcies        77159 non-null  int64
#  90  tax_liens                   77159 non-null  int64
# dtypes: float64(45), int64(39), object(7)
# memory usage: 53.6+ MB

# %%
remaining_categorical_features = transformed_loan_df.select_dtypes(exclude=[np.number])
print(len(remaining_categorical_features.columns))
# Out:
# 7

# %%
categorical_columns_to_drop = categorical_features_of_interest
categorical_columns_to_drop.append('loan_status')
dropable_categorical_columns = list(set(transformed_loan_df.columns) - set(categorical_columns_to_drop))
dropable_categorical_columns = transformed_loan_df[dropable_categorical_columns].select_dtypes(exclude=[np.number]).columns
dropable_categorical_columns
# Out:
# Index(['pymnt_plan', 'next_pymnt_d', 'earliest_cr_line', 'initial_list_status',
#        'issue_d', 'last_pymnt_d'],
#       dtype='object')

# %%
encoded_loan_df = transformed_loan_df.drop(dropable_categorical_columns, axis=1)
encoded_loan_df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77159 entries, 0 to 77158
# Data columns (total 85 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          77159 non-null  int64
#  1   emp_title                   71297 non-null  float64
#  2   application_type            77159 non-null  float64
#  3   home_ownership              77159 non-null  float64
#  4   loan_status                 77159 non-null  object
#  5   loan_amnt                   77159 non-null  int64
#  6   int_rate                    77159 non-null  float64
#  7   term                        77159 non-null  float64
#  8   installment                 77159 non-null  float64
#  9   grade                       77159 non-null  float64
#  10  annual_inc                  77159 non-null  float64
#  11  verification_status         77159 non-null  float64
#  12  purpose                     77159 non-null  float64
#  13  hardship_flag               75532 non-null  float64
#  14  dti                         77051 non-null  float64
#  15  delinq_2yrs                 77159 non-null  int64
#  16  inq_fi                      74664 non-null  float64
#  17  inq_last_12m                74664 non-null  float64
#  18  inq_last_6mths              77159 non-null  int64
#  19  fico_range_low              77159 non-null  int64
#  20  fico_range_high             77159 non-null  int64
#  21  last_fico_range_high        77159 non-null  int64
#  22  last_fico_range_low         77159 non-null  int64
#  23  mort_acc                    77159 non-null  int64
#  24  open_acc                    77159 non-null  int64
#  25  open_acc_6m                 74664 non-null  float64
#  26  acc_open_past_24mths        77159 non-null  int64
#  27  pub_rec                     77159 non-null  int64
#  28  total_acc                   77159 non-null  int64
#  29  out_prncp                   77159 non-null  float64
#  30  out_prncp_inv               77159 non-null  float64
#  31  total_pymnt                 77159 non-null  float64
#  32  total_pymnt_inv             77159 non-null  float64
#  33  total_rec_prncp             77159 non-null  float64
#  34  total_rec_int               77159 non-null  float64
#  35  total_rec_late_fee          77159 non-null  float64
#  36  total_cu_tl                 74664 non-null  float64
#  37  tot_coll_amt                77159 non-null  int64
#  38  tot_cur_bal                 77159 non-null  int64
#  39  total_bal_il                74664 non-null  float64
#  40  total_rev_hi_lim            77159 non-null  int64
#  41  tot_hi_cred_lim             77159 non-null  int64
#  42  total_bal_ex_mort           77159 non-null  int64
#  43  total_bc_limit              77159 non-null  int64
#  44  total_il_high_credit_limit  77159 non-null  int64
#  45  mths_since_recent_bc        76112 non-null  float64
#  46  mths_since_recent_inq       67916 non-null  float64
#  47  mths_since_rcnt_il          72280 non-null  float64
#  48  mths_since_last_delinq      37514 non-null  float64
#  49  mo_sin_old_il_acct          74722 non-null  float64
#  50  mo_sin_old_rev_tl_op        77159 non-null  int64
#  51  mo_sin_rcnt_rev_tl_op       77159 non-null  int64
#  52  mo_sin_rcnt_tl              77159 non-null  int64
#  53  open_act_il                 74664 non-null  float64
#  54  open_il_12m                 74664 non-null  float64
#  55  open_il_24m                 74664 non-null  float64
#  56  il_util                     63897 non-null  float64
#  57  bc_util                     76005 non-null  float64
#  58  all_util                    74648 non-null  float64
#  59  revol_util                  77056 non-null  float64
#  60  open_rv_12m                 74664 non-null  float64
#  61  open_rv_24m                 74664 non-null  float64
#  62  max_bal_bc                  74664 non-null  float64
#  63  avg_cur_bal                 77152 non-null  float64
#  64  bc_open_to_buy              76043 non-null  float64
#  65  recoveries                  77159 non-null  float64
#  66  chargeoff_within_12_mths    77159 non-null  int64
#  67  collection_recovery_fee     77159 non-null  float64
#  68  collections_12_mths_ex_med  77159 non-null  int64
#  69  num_accts_ever_120_pd       77159 non-null  int64
#  70  num_actv_bc_tl              77159 non-null  int64
#  71  num_actv_rev_tl             77159 non-null  int64
#  72  num_bc_sats                 77159 non-null  int64
#  73  num_bc_tl                   77159 non-null  int64
#  74  num_il_tl                   77159 non-null  int64
#  75  num_op_rev_tl               77159 non-null  int64
#  76  num_rev_accts               77159 non-null  int64
#  77  num_rev_tl_bal_gt_0         77159 non-null  int64
#  78  num_sats                    77159 non-null  int64
#  79  num_tl_90g_dpd_24m          77159 non-null  int64
#  80  num_tl_op_past_12m          77159 non-null  int64
#  81  pct_tl_nvr_dlq              77154 non-null  float64
#  82  percent_bc_gt_75            76040 non-null  float64
#  83  pub_rec_bankruptcies        77159 non-null  int64
#  84  tax_liens                   77159 non-null  int64
# dtypes: float64(45), int64(39), object(1)
# memory usage: 50.0+ MB

# %%
Y= encoded_loan_df['loan_status']
X= encoded_loan_df.drop(['loan_status'],axis = 1)
print(Y.sample(3))
print(X.info(verbose=True))
# Out:
# 29432    Fully Paid
# 66131    Fully Paid
# 14760    Fully Paid
# Name: loan_status, dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77159 entries, 0 to 77158
# Data columns (total 84 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          77159 non-null  int64
#  1   emp_title                   71297 non-null  float64
#  2   application_type            77159 non-null  float64
#  3   home_ownership              77159 non-null  float64
#  4   loan_amnt                   77159 non-null  int64
#  5   int_rate                    77159 non-null  float64
#  6   term                        77159 non-null  float64
#  7   installment                 77159 non-null  float64
#  8   grade                       77159 non-null  float64
#  9   annual_inc                  77159 non-null  float64
#  10  verification_status         77159 non-null  float64
#  11  purpose                     77159 non-null  float64
#  12  hardship_flag               75532 non-null  float64
#  13  dti                         77051 non-null  float64
#  14  delinq_2yrs                 77159 non-null  int64
#  15  inq_fi                      74664 non-null  float64
#  16  inq_last_12m                74664 non-null  float64
#  17  inq_last_6mths              77159 non-null  int64
#  18  fico_range_low              77159 non-null  int64
#  19  fico_range_high             77159 non-null  int64
#  20  last_fico_range_high        77159 non-null  int64
#  21  last_fico_range_low         77159 non-null  int64
#  22  mort_acc                    77159 non-null  int64
#  23  open_acc                    77159 non-null  int64
#  24  open_acc_6m                 74664 non-null  float64
#  25  acc_open_past_24mths        77159 non-null  int64
#  26  pub_rec                     77159 non-null  int64
#  27  total_acc                   77159 non-null  int64
#  28  out_prncp                   77159 non-null  float64
#  29  out_prncp_inv               77159 non-null  float64
#  30  total_pymnt                 77159 non-null  float64
#  31  total_pymnt_inv             77159 non-null  float64
#  32  total_rec_prncp             77159 non-null  float64
#  33  total_rec_int               77159 non-null  float64
#  34  total_rec_late_fee          77159 non-null  float64
#  35  total_cu_tl                 74664 non-null  float64
#  36  tot_coll_amt                77159 non-null  int64
#  37  tot_cur_bal                 77159 non-null  int64
#  38  total_bal_il                74664 non-null  float64
#  39  total_rev_hi_lim            77159 non-null  int64
#  40  tot_hi_cred_lim             77159 non-null  int64
#  41  total_bal_ex_mort           77159 non-null  int64
#  42  total_bc_limit              77159 non-null  int64
#  43  total_il_high_credit_limit  77159 non-null  int64
#  44  mths_since_recent_bc        76112 non-null  float64
#  45  mths_since_recent_inq       67916 non-null  float64
#  46  mths_since_rcnt_il          72280 non-null  float64
#  47  mths_since_last_delinq      37514 non-null  float64
#  48  mo_sin_old_il_acct          74722 non-null  float64
#  49  mo_sin_old_rev_tl_op        77159 non-null  int64
#  50  mo_sin_rcnt_rev_tl_op       77159 non-null  int64
#  51  mo_sin_rcnt_tl              77159 non-null  int64
#  52  open_act_il                 74664 non-null  float64
#  53  open_il_12m                 74664 non-null  float64
#  54  open_il_24m                 74664 non-null  float64
#  55  il_util                     63897 non-null  float64
#  56  bc_util                     76005 non-null  float64
#  57  all_util                    74648 non-null  float64
#  58  revol_util                  77056 non-null  float64
#  59  open_rv_12m                 74664 non-null  float64
#  60  open_rv_24m                 74664 non-null  float64
#  61  max_bal_bc                  74664 non-null  float64
#  62  avg_cur_bal                 77152 non-null  float64
#  63  bc_open_to_buy              76043 non-null  float64
#  64  recoveries                  77159 non-null  float64
#  65  chargeoff_within_12_mths    77159 non-null  int64
#  66  collection_recovery_fee     77159 non-null  float64
#  67  collections_12_mths_ex_med  77159 non-null  int64
#  68  num_accts_ever_120_pd       77159 non-null  int64
#  69  num_actv_bc_tl              77159 non-null  int64
#  70  num_actv_rev_tl             77159 non-null  int64
#  71  num_bc_sats                 77159 non-null  int64
#  72  num_bc_tl                   77159 non-null  int64
#  73  num_il_tl                   77159 non-null  int64
#  74  num_op_rev_tl               77159 non-null  int64
#  75  num_rev_accts               77159 non-null  int64
#  76  num_rev_tl_bal_gt_0         77159 non-null  int64
#  77  num_sats                    77159 non-null  int64
#  78  num_tl_90g_dpd_24m          77159 non-null  int64
#  79  num_tl_op_past_12m          77159 non-null  int64
#  80  pct_tl_nvr_dlq              77154 non-null  float64
#  81  percent_bc_gt_75            76040 non-null  float64
#  82  pub_rec_bankruptcies        77159 non-null  int64
#  83  tax_liens                   77159 non-null  int64
# dtypes: float64(45), int64(39)
# memory usage: 49.4 MB
# None

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=1)

# %%
print(X_train.describe())
print(y_train.sample(3))
# Out:
#                  id     emp_title  application_type  home_ownership  \
# count  6.172700e+04  57001.000000      61727.000000    61727.000000
# mean   1.152615e+08   7034.572499          1.121357        1.717417
# std    2.033732e+07   8289.984824          0.326544        0.661276
# min    1.227221e+06      1.000000          1.000000        1.000000
# 25%    1.141648e+08    405.000000          1.000000        1.000000
# 50%    1.178802e+08   2836.000000          1.000000        2.000000
# 75%    1.248018e+08  12268.000000          1.000000        2.000000
# max    1.264174e+08  28186.000000          2.000000        4.000000
#
#           loan_amnt      int_rate          term   installment         grade  \
# count  61727.000000  61727.000000  61727.000000  61727.000000  61727.000000
# mean   15151.520404     15.112107      1.315502    443.036455      2.680448
# std     9752.390840     14.658610      0.464719    280.177288      1.433623
# min     1000.000000      1.000000      1.000000     25.860000      1.000000
# 25%     7800.000000      7.000000      1.000000    239.520000      1.000000
# 50%    12000.000000     11.000000      1.000000    369.000000      3.000000
# 75%    20000.000000     21.000000      2.000000    590.755000      4.000000
# max    40000.000000    129.000000      2.000000   1717.630000      7.000000
#
#          annual_inc  ...  num_op_rev_tl  num_rev_accts  num_rev_tl_bal_gt_0  \
# count  6.172700e+04  ...   61727.000000   61727.000000         61727.000000
# mean   7.843127e+04  ...       8.024333      12.975732             5.374196
# std    9.016921e+04  ...       4.754862       7.790406             3.286360
# min    0.000000e+00  ...       0.000000       2.000000             0.000000
# 25%    4.500000e+04  ...       5.000000       7.000000             3.000000
# 50%    6.500000e+04  ...       7.000000      11.000000             5.000000
# 75%    9.400000e+04  ...      10.000000      17.000000             7.000000
# max    1.099920e+07  ...      63.000000     107.000000            39.000000
#
#            num_sats  num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# count  61727.000000        61727.000000        61727.000000    61723.000000
# mean      11.439662            0.086559            1.953213       93.780333
# std        5.746761            0.554932            1.775371        9.738220
# min        0.000000            0.000000            0.000000       12.500000
# 25%        7.000000            0.000000            1.000000       90.900000
# 50%       10.000000            0.000000            2.000000      100.000000
# 75%       14.000000            0.000000            3.000000      100.000000
# max       74.000000           30.000000           23.000000      100.000000
#
#        percent_bc_gt_75  pub_rec_bankruptcies     tax_liens
# count      60808.000000          61727.000000  61727.000000
# mean          38.400481              0.128372      0.039739
# std           36.260274              0.347150      0.367567
# min            0.000000              0.000000      0.000000
# 25%            0.000000              0.000000      0.000000
# 50%           33.300000              0.000000      0.000000
# 75%           66.700000              0.000000      0.000000
# max          100.000000              6.000000     44.000000
#
# [8 rows x 84 columns]
# 1598      Fully Paid
# 24298        Current
# 65762    Charged Off
# Name: loan_status, dtype: object

# %%
plt.figure(figsize=(15, 10))
sns.countplot(x='loan_status', data=y_train.to_frame())
plt.show()

# %%
plt.figure(figsize=(50, 50))
sns.boxplot(data=X_train).set(yscale="log")
plt.show()

# %%
for feature in X_train:
    print(feature)
    sns.boxplot(x=feature, data=X_train)
    plt.show()
# Out:
# id
# emp_title
# application_type
# home_ownership
# loan_amnt
# int_rate
# term
# installment
# grade
# annual_inc
# verification_status
# purpose
# hardship_flag
# dti
# delinq_2yrs
# inq_fi
# inq_last_12m
# inq_last_6mths
# fico_range_low
# fico_range_high
# last_fico_range_high
# last_fico_range_low
# mort_acc
# open_acc
# open_acc_6m
# acc_open_past_24mths
# pub_rec
# total_acc
# out_prncp
# out_prncp_inv
# total_pymnt
# total_pymnt_inv
# total_rec_prncp
# total_rec_int
# total_rec_late_fee
# total_cu_tl
# tot_coll_amt
# tot_cur_bal
# total_bal_il
# total_rev_hi_lim
# tot_hi_cred_lim
# total_bal_ex_mort
# total_bc_limit
# total_il_high_credit_limit
# mths_since_recent_bc
# mths_since_recent_inq
# mths_since_rcnt_il
# mths_since_last_delinq
# mo_sin_old_il_acct
# mo_sin_old_rev_tl_op
# mo_sin_rcnt_rev_tl_op
# mo_sin_rcnt_tl
# open_act_il
# open_il_12m
# open_il_24m
# il_util
# bc_util
# all_util
# revol_util
# open_rv_12m
# open_rv_24m
# max_bal_bc
# avg_cur_bal
# bc_open_to_buy
# recoveries
# chargeoff_within_12_mths
# collection_recovery_fee
# collections_12_mths_ex_med
# num_accts_ever_120_pd
# num_actv_bc_tl
# num_actv_rev_tl
# num_bc_sats
# num_bc_tl
# num_il_tl
# num_op_rev_tl
# num_rev_accts
# num_rev_tl_bal_gt_0
# num_sats
# num_tl_90g_dpd_24m
# num_tl_op_past_12m
# pct_tl_nvr_dlq
# percent_bc_gt_75
# pub_rec_bankruptcies
# tax_liens

# %%
#print(X_train.isna().sum())
for i in X_train:
    print(i, X_train[i].isna().sum())
# Out:
# id 0
# emp_title 4726
# application_type 0
# home_ownership 0
# loan_amnt 0
# int_rate 0
# term 0
# installment 0
# grade 0
# annual_inc 0
# verification_status 0
# purpose 0
# hardship_flag 1299
# dti 81
# delinq_2yrs 0
# inq_fi 1999
# inq_last_12m 1999
# inq_last_6mths 0
# fico_range_low 0
# fico_range_high 0
# last_fico_range_high 0
# last_fico_range_low 0
# mort_acc 0
# open_acc 0
# open_acc_6m 1999
# acc_open_past_24mths 0
# pub_rec 0
# total_acc 0
# out_prncp 0
# out_prncp_inv 0
# total_pymnt 0
# total_pymnt_inv 0
# total_rec_prncp 0
# total_rec_int 0
# total_rec_late_fee 0
# total_cu_tl 1999
# tot_coll_amt 0
# tot_cur_bal 0
# total_bal_il 1999
# total_rev_hi_lim 0
# tot_hi_cred_lim 0
# total_bal_ex_mort 0
# total_bc_limit 0
# total_il_high_credit_limit 0
# mths_since_recent_bc 857
# mths_since_recent_inq 7414
# mths_since_rcnt_il 3905
# mths_since_last_delinq 31760
# mo_sin_old_il_acct 1951
# mo_sin_old_rev_tl_op 0
# mo_sin_rcnt_rev_tl_op 0
# mo_sin_rcnt_tl 0
# open_act_il 1999
# open_il_12m 1999
# open_il_24m 1999
# il_util 10580
# bc_util 946
# all_util 2014
# revol_util 83
# open_rv_12m 1999
# open_rv_24m 1999
# max_bal_bc 1999
# avg_cur_bal 7
# bc_open_to_buy 916
# recoveries 0
# chargeoff_within_12_mths 0
# collection_recovery_fee 0
# collections_12_mths_ex_med 0
# num_accts_ever_120_pd 0
# num_actv_bc_tl 0
# num_actv_rev_tl 0
# num_bc_sats 0
# num_bc_tl 0
# num_il_tl 0
# num_op_rev_tl 0
# num_rev_accts 0
# num_rev_tl_bal_gt_0 0
# num_sats 0
# num_tl_90g_dpd_24m 0
# num_tl_op_past_12m 0
# pct_tl_nvr_dlq 4
# percent_bc_gt_75 919
# pub_rec_bankruptcies 0
# tax_liens 0

# %%
X_train.describe()
# Out:
#                  id     emp_title  application_type  home_ownership  \
# count  6.172700e+04  57001.000000      61727.000000    61727.000000
# mean   1.152615e+08   7034.572499          1.121357        1.717417
# std    2.033732e+07   8289.984824          0.326544        0.661276
# min    1.227221e+06      1.000000          1.000000        1.000000
# 25%    1.141648e+08    405.000000          1.000000        1.000000
# 50%    1.178802e+08   2836.000000          1.000000        2.000000
# 75%    1.248018e+08  12268.000000          1.000000        2.000000
# max    1.264174e+08  28186.000000          2.000000        4.000000
#
#           loan_amnt      int_rate          term   installment         grade  \
# count  61727.000000  61727.000000  61727.000000  61727.000000  61727.000000
# mean   15151.520404     15.112107      1.315502    443.036455      2.680448
# std     9752.390840     14.658610      0.464719    280.177288      1.433623
# min     1000.000000      1.000000      1.000000     25.860000      1.000000
# 25%     7800.000000      7.000000      1.000000    239.520000      1.000000
# 50%    12000.000000     11.000000      1.000000    369.000000      3.000000
# 75%    20000.000000     21.000000      2.000000    590.755000      4.000000
# max    40000.000000    129.000000      2.000000   1717.630000      7.000000
#
#          annual_inc  ...  num_op_rev_tl  num_rev_accts  num_rev_tl_bal_gt_0  \
# count  6.172700e+04  ...   61727.000000   61727.000000         61727.000000
# mean   7.843127e+04  ...       8.024333      12.975732             5.374196
# std    9.016921e+04  ...       4.754862       7.790406             3.286360
# min    0.000000e+00  ...       0.000000       2.000000             0.000000
# 25%    4.500000e+04  ...       5.000000       7.000000             3.000000
# 50%    6.500000e+04  ...       7.000000      11.000000             5.000000
# 75%    9.400000e+04  ...      10.000000      17.000000             7.000000
# max    1.099920e+07  ...      63.000000     107.000000            39.000000
#
#            num_sats  num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# count  61727.000000        61727.000000        61727.000000    61723.000000
# mean      11.439662            0.086559            1.953213       93.780333
# std        5.746761            0.554932            1.775371        9.738220
# min        0.000000            0.000000            0.000000       12.500000
# 25%        7.000000            0.000000            1.000000       90.900000
# 50%       10.000000            0.000000            2.000000      100.000000
# 75%       14.000000            0.000000            3.000000      100.000000
# max       74.000000           30.000000           23.000000      100.000000
#
#        percent_bc_gt_75  pub_rec_bankruptcies     tax_liens
# count      60808.000000          61727.000000  61727.000000
# mean          38.400481              0.128372      0.039739
# std           36.260274              0.347150      0.367567
# min            0.000000              0.000000      0.000000
# 25%            0.000000              0.000000      0.000000
# 50%           33.300000              0.000000      0.000000
# 75%           66.700000              0.000000      0.000000
# max          100.000000              6.000000     44.000000
#
# [8 rows x 84 columns]

# %%
corr = X_train.corr()
corr
plt.figure(figsize=(12,10))
sns.heatmap(corr, annot=False, cmap=plt.cm.Reds)w
plt.show()

# %%
columns = np.full((corr.shape[0],), True, dtype=bool)
for i in range(corr.shape[0]):
    for j in range(i+1, corr.shape[0]):
        if corr.iloc[i,j] >= 0.7:
            if columns[j]:
                columns[j] = False
selected_columns = X_train.columns[columns]
# data = X_train[selected_columns]
print(len(selected_columns))
print(selected_columns)
# Out:
# 55
# Index(['id', 'emp_title', 'application_type', 'home_ownership', 'loan_amnt',
#        'int_rate', 'term', 'grade', 'annual_inc', 'verification_status',
#        'purpose', 'hardship_flag', 'dti', 'delinq_2yrs', 'inq_fi',
#        'inq_last_12m', 'inq_last_6mths', 'fico_range_low',
#        'last_fico_range_high', 'mort_acc', 'open_acc', 'open_acc_6m',
#        'acc_open_past_24mths', 'pub_rec', 'out_prncp', 'total_rec_late_fee',
#        'total_cu_tl', 'tot_coll_amt', 'tot_cur_bal', 'total_bal_il',
#        'total_rev_hi_lim', 'mths_since_recent_bc', 'mths_since_recent_inq',
#        'mths_since_rcnt_il', 'mths_since_last_delinq', 'mo_sin_old_il_acct',
#        'mo_sin_old_rev_tl_op', 'mo_sin_rcnt_rev_tl_op', 'mo_sin_rcnt_tl',
#        'open_act_il', 'open_il_12m', 'il_util', 'bc_util', 'all_util',
#        'revol_util', 'open_rv_12m', 'max_bal_bc', 'recoveries',
#        'chargeoff_within_12_mths', 'collections_12_mths_ex_med',
#        'num_accts_ever_120_pd', 'num_actv_bc_tl', 'num_tl_90g_dpd_24m',
#        'pct_tl_nvr_dlq', 'pub_rec_bankruptcies'],
#       dtype='object')

# %%
def quntile_check(feature):
    df = X_train.sort_values([feature], ascending=True)
    q3, q1 = np.percentile(df[feature], [75 ,25])
    iqr = q3 - q1
    iqr
    lower_limit = q1 - 1.5 * iqr
    upper_limit = q3 + 1.5 * iqr
    outliers = X_train[(X_train[feature] < lower_limit) | (X_train[feature] > upper_limit)]
    # print(outliers.index.tolist())
    # print(outliers.head())
    # print(outliers.tail())
    print('Feature Name::::::::::::', feature)
    print('Total Length :::::::::::', len(X_train))
    print('Impure Length ::::::::::', len(outliers))
    print('Pure Length:::::::::::::', len(X_train[~X_train.index.isin(outliers.index.tolist())]))
    sns.boxplot(x=feature, data=X_train)
    plt.show()
    print('-------------------------------------------------------------------')
    return outliers.index.tolist()
    # print(X_train[~X_train.index.isin(outliers.index.tolist())])
    # for i in outliers:
    #     print(i)
    #     if (i == 'loan_amnt'):
    #         if ((outliers[i] < lower_limit) | (outliers[i] > upper_limit)):
    #             print(((outliers[i] < lower_limit) | (outliers[i] > upper_limit)))
    # print(outliers.head())
    # print(X_train[!((X_train['loan_amnt'] < lower_limit) | (X_train['loan_amnt'] > upper_limit))])
    # print(iqr, lower_limit, upper_limit)


# uncorrelatedFeature = np.setdiff1d(X_train.columns, selected_columns)
# print(len(uncorrelatedFeature))
featureOutiers = []
for i in X_train:
#     print(i)
    featureOutiers.append(quntile_check(i))
# Out:
# Feature Name:::::::::::: id
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 2014
# Pure Length::::::::::::: 59713
# -------------------------------------------------------------------
# Feature Name:::::::::::: emp_title
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 0
# Pure Length::::::::::::: 61727
# -------------------------------------------------------------------
# Feature Name:::::::::::: application_type
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 7491
# Pure Length::::::::::::: 54236
# -------------------------------------------------------------------
# Feature Name:::::::::::: home_ownership
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 1
# Pure Length::::::::::::: 61726
# -------------------------------------------------------------------
# Feature Name:::::::::::: loan_amnt
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 1741
# Pure Length::::::::::::: 59986
# -------------------------------------------------------------------
# Feature Name:::::::::::: int_rate
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 2300
# Pure Length::::::::::::: 59427
# -------------------------------------------------------------------
# Feature Name:::::::::::: term
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 0
# Pure Length::::::::::::: 61727
# -------------------------------------------------------------------
# Feature Name:::::::::::: installment
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 2074
# Pure Length::::::::::::: 59653
# -------------------------------------------------------------------
# Feature Name:::::::::::: grade
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 0
# Pure Length::::::::::::: 61727
# -------------------------------------------------------------------
# Feature Name:::::::::::: annual_inc
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 3038
# Pure Length::::::::::::: 58689
# -------------------------------------------------------------------
# Feature Name:::::::::::: verification_status
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 0
# Pure Length::::::::::::: 61727
# -------------------------------------------------------------------
# Feature Name:::::::::::: purpose
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 35
# Pure Length::::::::::::: 61692
# -------------------------------------------------------------------
# Feature Name:::::::::::: hardship_flag
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 0
# Pure Length::::::::::::: 61727
# -------------------------------------------------------------------
# Feature Name:::::::::::: dti
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 0
# Pure Length::::::::::::: 61727
# -------------------------------------------------------------------
# Feature Name:::::::::::: delinq_2yrs
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 11788
# Pure Length::::::::::::: 49939
# -------------------------------------------------------------------
# Feature Name:::::::::::: inq_fi
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 0
# Pure Length::::::::::::: 61727
# -------------------------------------------------------------------
# Feature Name:::::::::::: inq_last_12m
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 0
# Pure Length::::::::::::: 61727
# -------------------------------------------------------------------
# Feature Name:::::::::::: inq_last_6mths
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 1765
# Pure Length::::::::::::: 59962
# -------------------------------------------------------------------
# Feature Name:::::::::::: fico_range_low
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 1753
# Pure Length::::::::::::: 59974
# -------------------------------------------------------------------
# Feature Name:::::::::::: fico_range_high
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 1753
# Pure Length::::::::::::: 59974
# -------------------------------------------------------------------
# Feature Name:::::::::::: last_fico_range_high
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 2529
# Pure Length::::::::::::: 59198
# -------------------------------------------------------------------
# Feature Name:::::::::::: last_fico_range_low
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 2529
# Pure Length::::::::::::: 59198
# -------------------------------------------------------------------
# Feature Name:::::::::::: mort_acc
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 1751
# Pure Length::::::::::::: 59976
# -------------------------------------------------------------------
# Feature Name:::::::::::: open_acc
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 1948
# Pure Length::::::::::::: 59779
# -------------------------------------------------------------------
# Feature Name:::::::::::: open_acc_6m
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 0
# Pure Length::::::::::::: 61727
# -------------------------------------------------------------------
# Feature Name:::::::::::: acc_open_past_24mths
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 1180
# Pure Length::::::::::::: 60547
# -------------------------------------------------------------------
# Feature Name:::::::::::: pub_rec
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 9125
# Pure Length::::::::::::: 52602
# -------------------------------------------------------------------
# Feature Name:::::::::::: total_acc
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 1439
# Pure Length::::::::::::: 60288
# -------------------------------------------------------------------
# Feature Name:::::::::::: out_prncp
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 10743
# Pure Length::::::::::::: 50984
# -------------------------------------------------------------------
# Feature Name:::::::::::: out_prncp_inv
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 10744
# Pure Length::::::::::::: 50983
# -------------------------------------------------------------------
# Feature Name:::::::::::: total_pymnt
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 2276
# Pure Length::::::::::::: 59451
# -------------------------------------------------------------------
# Feature Name:::::::::::: total_pymnt_inv
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 2273
# Pure Length::::::::::::: 59454
# -------------------------------------------------------------------
# Feature Name:::::::::::: total_rec_prncp
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 2818
# Pure Length::::::::::::: 58909
# -------------------------------------------------------------------
# Feature Name:::::::::::: total_rec_int
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 3458
# Pure Length::::::::::::: 58269
# -------------------------------------------------------------------
# Feature Name:::::::::::: total_rec_late_fee
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 4023
# Pure Length::::::::::::: 57704
# -------------------------------------------------------------------
# Feature Name:::::::::::: total_cu_tl
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 0
# Pure Length::::::::::::: 61727
# -------------------------------------------------------------------
# Feature Name:::::::::::: tot_coll_amt
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 9804
# Pure Length::::::::::::: 51923
# -------------------------------------------------------------------
# Feature Name:::::::::::: tot_cur_bal
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 2228
# Pure Length::::::::::::: 59499
# -------------------------------------------------------------------
# Feature Name:::::::::::: total_bal_il
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 0
# Pure Length::::::::::::: 61727
# -------------------------------------------------------------------
# Feature Name:::::::::::: total_rev_hi_lim
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 3494
# Pure Length::::::::::::: 58233
# -------------------------------------------------------------------
# Feature Name:::::::::::: tot_hi_cred_lim
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 2163
# Pure Length::::::::::::: 59564
# -------------------------------------------------------------------
# Feature Name:::::::::::: total_bal_ex_mort
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 3719
# Pure Length::::::::::::: 58008
# -------------------------------------------------------------------
# Feature Name:::::::::::: total_bc_limit
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 3542
# Pure Length::::::::::::: 58185
# -------------------------------------------------------------------
# Feature Name:::::::::::: total_il_high_credit_limit
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 3209
# Pure Length::::::::::::: 58518
# -------------------------------------------------------------------
# Feature Name:::::::::::: mths_since_recent_bc
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 0
# Pure Length::::::::::::: 61727
# -------------------------------------------------------------------
# Feature Name:::::::::::: mths_since_recent_inq
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 0
# Pure Length::::::::::::: 61727
# -------------------------------------------------------------------
# Feature Name:::::::::::: mths_since_rcnt_il
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 0
# Pure Length::::::::::::: 61727
# -------------------------------------------------------------------
# Feature Name:::::::::::: mths_since_last_delinq
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 0
# Pure Length::::::::::::: 61727
# -------------------------------------------------------------------
# Feature Name:::::::::::: mo_sin_old_il_acct
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 0
# Pure Length::::::::::::: 61727
# -------------------------------------------------------------------
# Feature Name:::::::::::: mo_sin_old_rev_tl_op
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 1800
# Pure Length::::::::::::: 59927
# -------------------------------------------------------------------
# Feature Name:::::::::::: mo_sin_rcnt_rev_tl_op
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 4415
# Pure Length::::::::::::: 57312
# -------------------------------------------------------------------
# Feature Name:::::::::::: mo_sin_rcnt_tl
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 3453
# Pure Length::::::::::::: 58274
# -------------------------------------------------------------------
# Feature Name:::::::::::: open_act_il
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 0
# Pure Length::::::::::::: 61727
# -------------------------------------------------------------------
# Feature Name:::::::::::: open_il_12m
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 0
# Pure Length::::::::::::: 61727
# -------------------------------------------------------------------
# Feature Name:::::::::::: open_il_24m
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 0
# Pure Length::::::::::::: 61727
# -------------------------------------------------------------------
# Feature Name:::::::::::: il_util
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 0
# Pure Length::::::::::::: 61727
# -------------------------------------------------------------------
# Feature Name:::::::::::: bc_util
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 0
# Pure Length::::::::::::: 61727
# -------------------------------------------------------------------
# Feature Name:::::::::::: all_util
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 0
# Pure Length::::::::::::: 61727
# -------------------------------------------------------------------
# Feature Name:::::::::::: revol_util
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 0
# Pure Length::::::::::::: 61727
# -------------------------------------------------------------------
# Feature Name:::::::::::: open_rv_12m
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 0
# Pure Length::::::::::::: 61727
# -------------------------------------------------------------------
# Feature Name:::::::::::: open_rv_24m
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 0
# Pure Length::::::::::::: 61727
# -------------------------------------------------------------------
# Feature Name:::::::::::: max_bal_bc
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 0
# Pure Length::::::::::::: 61727
# -------------------------------------------------------------------
# Feature Name:::::::::::: avg_cur_bal
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 0
# Pure Length::::::::::::: 61727
# -------------------------------------------------------------------
# Feature Name:::::::::::: bc_open_to_buy
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 0
# Pure Length::::::::::::: 61727
# -------------------------------------------------------------------
# Feature Name:::::::::::: recoveries
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 5407
# Pure Length::::::::::::: 56320
# -------------------------------------------------------------------
# Feature Name:::::::::::: chargeoff_within_12_mths
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 477
# Pure Length::::::::::::: 61250
# -------------------------------------------------------------------
# Feature Name:::::::::::: collection_recovery_fee
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 5407
# Pure Length::::::::::::: 56320
# -------------------------------------------------------------------
# Feature Name:::::::::::: collections_12_mths_ex_med
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 1279
# Pure Length::::::::::::: 60448
# -------------------------------------------------------------------
# Feature Name:::::::::::: num_accts_ever_120_pd
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 13809
# Pure Length::::::::::::: 47918
# -------------------------------------------------------------------
# Feature Name:::::::::::: num_actv_bc_tl
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 1530
# Pure Length::::::::::::: 60197
# -------------------------------------------------------------------
# Feature Name:::::::::::: num_actv_rev_tl
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 1867
# Pure Length::::::::::::: 59860
# -------------------------------------------------------------------
# Feature Name:::::::::::: num_bc_sats
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 3166
# Pure Length::::::::::::: 58561
# -------------------------------------------------------------------
# Feature Name:::::::::::: num_bc_tl
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 2399
# Pure Length::::::::::::: 59328
# -------------------------------------------------------------------
# Feature Name:::::::::::: num_il_tl
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 2713
# Pure Length::::::::::::: 59014
# -------------------------------------------------------------------
# Feature Name:::::::::::: num_op_rev_tl
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 2768
# Pure Length::::::::::::: 58959
# -------------------------------------------------------------------
# Feature Name:::::::::::: num_rev_accts
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 1513
# Pure Length::::::::::::: 60214
# -------------------------------------------------------------------
# Feature Name:::::::::::: num_rev_tl_bal_gt_0
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 1616
# Pure Length::::::::::::: 60111
# -------------------------------------------------------------------
# Feature Name:::::::::::: num_sats
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 1921
# Pure Length::::::::::::: 59806
# -------------------------------------------------------------------
# Feature Name:::::::::::: num_tl_90g_dpd_24m
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 3280
# Pure Length::::::::::::: 58447
# -------------------------------------------------------------------
# Feature Name:::::::::::: num_tl_op_past_12m
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 1346
# Pure Length::::::::::::: 60381
# -------------------------------------------------------------------
# Feature Name:::::::::::: pct_tl_nvr_dlq
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 0
# Pure Length::::::::::::: 61727
# -------------------------------------------------------------------
# Feature Name:::::::::::: percent_bc_gt_75
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 0
# Pure Length::::::::::::: 61727
# -------------------------------------------------------------------
# Feature Name:::::::::::: pub_rec_bankruptcies
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 7717
# Pure Length::::::::::::: 54010
# -------------------------------------------------------------------
# Feature Name:::::::::::: tax_liens
# Total Length ::::::::::: 61727
# Impure Length :::::::::: 1527
# Pure Length::::::::::::: 60200
# -------------------------------------------------------------------

# %%
# print(featureOutiers[3])
def unique_values_in_list_of_lists(lst):
    result = set(x for l in lst for x in l)
    return list(result)

values = unique_values_in_list_of_lists(featureOutiers)
print(len(values))
print(len(values) != len(set(values)))
# Out:
# 51992
# False

# %%
# from itertools import chain
# print(len(set(chain(*featureOutiers))))
# print(len(X_train))
X_train.describe()
# Out:
#                  id     emp_title  application_type  home_ownership  \
# count  6.172700e+04  57001.000000      61727.000000    61727.000000
# mean   1.152615e+08   7034.572499          1.121357        1.717417
# std    2.033732e+07   8289.984824          0.326544        0.661276
# min    1.227221e+06      1.000000          1.000000        1.000000
# 25%    1.141648e+08    405.000000          1.000000        1.000000
# 50%    1.178802e+08   2836.000000          1.000000        2.000000
# 75%    1.248018e+08  12268.000000          1.000000        2.000000
# max    1.264174e+08  28186.000000          2.000000        4.000000
#
#           loan_amnt      int_rate          term   installment         grade  \
# count  61727.000000  61727.000000  61727.000000  61727.000000  61727.000000
# mean   15151.520404     15.112107      1.315502    443.036455      2.680448
# std     9752.390840     14.658610      0.464719    280.177288      1.433623
# min     1000.000000      1.000000      1.000000     25.860000      1.000000
# 25%     7800.000000      7.000000      1.000000    239.520000      1.000000
# 50%    12000.000000     11.000000      1.000000    369.000000      3.000000
# 75%    20000.000000     21.000000      2.000000    590.755000      4.000000
# max    40000.000000    129.000000      2.000000   1717.630000      7.000000
#
#          annual_inc  ...  num_op_rev_tl  num_rev_accts  num_rev_tl_bal_gt_0  \
# count  6.172700e+04  ...   61727.000000   61727.000000         61727.000000
# mean   7.843127e+04  ...       8.024333      12.975732             5.374196
# std    9.016921e+04  ...       4.754862       7.790406             3.286360
# min    0.000000e+00  ...       0.000000       2.000000             0.000000
# 25%    4.500000e+04  ...       5.000000       7.000000             3.000000
# 50%    6.500000e+04  ...       7.000000      11.000000             5.000000
# 75%    9.400000e+04  ...      10.000000      17.000000             7.000000
# max    1.099920e+07  ...      63.000000     107.000000            39.000000
#
#            num_sats  num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# count  61727.000000        61727.000000        61727.000000    61723.000000
# mean      11.439662            0.086559            1.953213       93.780333
# std        5.746761            0.554932            1.775371        9.738220
# min        0.000000            0.000000            0.000000       12.500000
# 25%        7.000000            0.000000            1.000000       90.900000
# 50%       10.000000            0.000000            2.000000      100.000000
# 75%       14.000000            0.000000            3.000000      100.000000
# max       74.000000           30.000000           23.000000      100.000000
#
#        percent_bc_gt_75  pub_rec_bankruptcies     tax_liens
# count      60808.000000          61727.000000  61727.000000
# mean          38.400481              0.128372      0.039739
# std           36.260274              0.347150      0.367567
# min            0.000000              0.000000      0.000000
# 25%            0.000000              0.000000      0.000000
# 50%           33.300000              0.000000      0.000000
# 75%           66.700000              0.000000      0.000000
# max          100.000000              6.000000     44.000000
#
# [8 rows x 84 columns]

# %%
# Dealing with missing values
# #import the relevant methods
# from sklearn.impute import KNNImputer
# nan = np.nan

# #Apply KNN imputer
# imputer = KNNImputer(n_neighbors=2, weights="uniform")
# ImputedX=imputer.fit_transform(X_train)

# # Convert output to a data frame to show the stats
# dataframe = pd.DataFrame.from_records(ImputedX)
# dataframe.columns = X_train.columns
# dataframe.describe()
print(X_train.isna().sum())
X1_train = X_train.fillna(df.mean())
print(X1_train.isna().sum())
# Out:
# id                         0
# emp_title               4726
# application_type           0
# home_ownership             0
# loan_amnt                  0
#                         ...
# num_tl_op_past_12m         0
# pct_tl_nvr_dlq             4
# percent_bc_gt_75         919
# pub_rec_bankruptcies       0
# tax_liens                  0
# Length: 84, dtype: int64
# id                      0
# emp_title               0
# application_type        0
# home_ownership          0
# loan_amnt               0
#                        ..
# num_tl_op_past_12m      0
# pct_tl_nvr_dlq          0
# percent_bc_gt_75        0
# pub_rec_bankruptcies    0
# tax_liens               0
# Length: 84, dtype: int64

# %%
from sklearn.neighbors import LocalOutlierFactor
np.random.seed(42)

# fit the model for outlier detection (default)
clf = LocalOutlierFactor(n_neighbors=20, contamination="auto")

y_pred = clf.fit_predict(X1_train)

print ("Predicted outliers: \n",y_pred)

#Calculate number of outliers
outlierN = len([i for i in y_pred if i == -1])
print ("Number of predicted outliers:",outlierN)
# Out:
# Predicted outliers:
#  [1 1 1 ... 1 1 1]
# Number of predicted outliers: 1451

# %%
# Out:
#                             id  emp_title  application_type  home_ownership  \
# id                    1.000000  -0.102192          0.076127       -0.013219
# emp_title            -0.102192   1.000000         -0.015874       -0.013896
# application_type      0.076127  -0.015874          1.000000        0.074187
# home_ownership       -0.013219  -0.013896          0.074187        1.000000
# loan_amnt            -0.087494  -0.000890          0.162219        0.101500
# ...                        ...        ...               ...             ...
# num_tl_op_past_12m    0.042597  -0.008989         -0.032095        0.054837
# pct_tl_nvr_dlq       -0.017113   0.013051          0.022816       -0.008424
# percent_bc_gt_75     -0.118078   0.019267          0.017750       -0.017943
# pub_rec_bankruptcies  0.027801   0.001682          0.000053       -0.004927
# tax_liens             0.006756  -0.014475         -0.017505       -0.000322
#
#                       loan_amnt  int_rate      term  installment     grade  \
# id                    -0.087494 -0.580593 -0.257005    -0.041253  0.003697
# emp_title             -0.000890  0.063973  0.032637    -0.008029  0.002211
# application_type       0.162219 -0.047894  0.103509     0.140302 -0.012743
# home_ownership         0.101500  0.022388  0.064437     0.079902  0.012339
# loan_amnt              1.000000  0.064595  0.416321     0.944610 -0.013936
# ...                         ...       ...       ...          ...       ...
# num_tl_op_past_12m    -0.021650 -0.031232 -0.008676     0.001775 -0.008471
# pct_tl_nvr_dlq         0.091118  0.066403  0.047691     0.068798  0.028903
# percent_bc_gt_75       0.034306 -0.031935  0.064669     0.060403 -0.098826
# pub_rec_bankruptcies  -0.053575 -0.046883 -0.003519    -0.044950 -0.010673
# tax_liens              0.007575 -0.011642 -0.009572     0.014572 -0.007567
#
#                       annual_inc  ...  num_op_rev_tl  num_rev_accts  \
# id                      0.001538  ...      -0.026065      -0.055043
# emp_title              -0.006888  ...      -0.002296      -0.000736
# application_type       -0.086756  ...      -0.039141      -0.027468
# home_ownership          0.062390  ...       0.086249       0.128954
# loan_amnt               0.246794  ...       0.161424       0.173437
# ...                          ...  ...            ...            ...
# num_tl_op_past_12m      0.049026  ...       0.366731       0.318304
# pct_tl_nvr_dlq         -0.013335  ...       0.134958       0.058144
# percent_bc_gt_75        0.007117  ...      -0.131484      -0.116916
# pub_rec_bankruptcies   -0.024338  ...       0.026089       0.034614
# tax_liens               0.028306  ...      -0.001897      -0.012302
#
#                       num_rev_tl_bal_gt_0  num_sats  num_tl_90g_dpd_24m  \
# id                              -0.057962 -0.015633           -0.003525
# emp_title                        0.005132 -0.009340           -0.004706
# application_type                -0.045970 -0.026189           -0.013089
# home_ownership                   0.060340  0.090540           -0.009146
# loan_amnt                        0.143817  0.181414           -0.020901
# ...                                   ...       ...                 ...
# num_tl_op_past_12m               0.265570  0.373053            0.012974
# pct_tl_nvr_dlq                   0.092179  0.096012           -0.258049
# percent_bc_gt_75                 0.096781 -0.082956           -0.002913
# pub_rec_bankruptcies             0.003207 -0.007251           -0.018155
# tax_liens                        0.001758 -0.008831           -0.005189
#
#                       num_tl_op_past_12m  pct_tl_nvr_dlq  percent_bc_gt_75  \
# id                              0.042597       -0.017113         -0.118078
# emp_title                      -0.008989        0.013051          0.019267
# application_type               -0.032095        0.022816          0.017750
# home_ownership                  0.054837       -0.008424         -0.017943
# loan_amnt                      -0.021650        0.091118          0.034306
# ...                                  ...             ...               ...
# num_tl_op_past_12m              1.000000        0.007437         -0.182206
# pct_tl_nvr_dlq                  0.007437        1.000000         -0.041091
# percent_bc_gt_75               -0.182206       -0.041091          1.000000
# pub_rec_bankruptcies            0.080744        0.089135         -0.013056
# tax_liens                       0.014145       -0.018238         -0.012123
#
#                       pub_rec_bankruptcies  tax_liens
# id                                0.027801   0.006756
# emp_title                         0.001682  -0.014475
# application_type                  0.000053  -0.017505
# home_ownership                   -0.004927  -0.000322
# loan_amnt                        -0.053575   0.007575
# ...                                    ...        ...
# num_tl_op_past_12m                0.080744   0.014145
# pct_tl_nvr_dlq                    0.089135  -0.018238
# percent_bc_gt_75                 -0.013056  -0.012123
# pub_rec_bankruptcies              1.000000   0.023121
# tax_liens                         0.023121   1.000000
#
# [84 rows x 84 columns]

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X1_train.values, i) for i in range(X1_train.shape[1])]
vif["features"] = X1_train.columns
vif
# Out:
#     VIF Factor              features
# 0    86.626111                    id
# 1     1.803507             emp_title
# 2    14.849426      application_type
# 3     9.309117        home_ownership
# 4   158.117633             loan_amnt
# ..         ...                   ...
# 79   72.252237    num_tl_op_past_12m
# 80  214.148377        pct_tl_nvr_dlq
# 81    7.981206      percent_bc_gt_75
# 82   20.051601  pub_rec_bankruptcies
# 83   20.354439             tax_liens
#
# [84 rows x 2 columns]
